# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
import os.path
from saveDataset import save_data

# Helper libraries
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
import glob, os
import re

# Pillow
import PIL
from PIL import Image

# %% [markdown]
# set rootpath= path of the directory containing 'image-recognition-tensorflow-master'

# %%
rootpath='D:\hackathon'

# %%
# Use Pillow library to convert an input jpeg to a 8 bit grey scale image array for processing.
def jpeg_to_8_bit_greyscale(path, maxsize):
        img = Image.open(path).convert('L')   # convert image to 8-bit grayscale
        # Make aspect ratio as 1:1, by applying image crop.
    # Please note, croping works for this data set, but in general one
    # needs to locate the subject and then crop or scale accordingly.
        WIDTH, HEIGHT = img.size
        if WIDTH != HEIGHT:
                m_min_d = min(WIDTH, HEIGHT)
                img = img.crop((0, 0, m_min_d, m_min_d))
        # Scale the image to the requested maxsize by Anti-alias sampling.
        img.thumbnail(maxsize, PIL.Image.ANTIALIAS)
        return np.asarray(img)

# %%
def load_image_dataset(path_dir, maxsize):
        images = []
        labels = []
        os.chdir(path_dir)
        for file in glob.glob("*.jpg"):
                img = jpeg_to_8_bit_greyscale(file, maxsize)
#                 if re.match('chihuahua.*', file):
                if re.match('plastic.*', file):
                        images.append(img)
                        labels.append(0)
#                 elif re.match('muffin.*', file):
                elif re.match('paper.*', file):
                        images.append(img)
                        labels.append(1)
                else:
                    images.append(img)
                    labels.append(1)
        return (np.array(images), np.array(labels))

# %%
def shuffle_examples(X,Y):
    dim= X.shape
    X= np.reshape(X,(X.shape[0],-1))
    Y=Y.reshape(-1,1)
    X= np.append(X, Y, axis=1)
    
    np.random.seed(0)
    np.random.shuffle(X)
    
    A=np.array([])
    
    for i in range(X.shape[1]-1):
        if i==0:
            A= np.array(X[:,i]).reshape(-1,1)
        else:
            A=np.append(A,np.array(X[:,i]).reshape(-1,1),axis=1)

    Y= np.array(X[:,X.shape[1]-1])
    
    A= np.reshape(A,dim)
    
    return A,Y

# %%
maxsize = 100, 100

# %%
if(os.path.exists(rootpath+'\image-recognition-tensorflow-master\train_images.npy')==False):
    (train_images, train_labels) = load_image_dataset(rootpath+'\image_classification\plastic_paper', maxsize)
    (test_images, test_labels) = load_image_dataset(rootpath+'\image_classification\plastic_paper\test_set', maxsize)

#     (train_images, train_labels) = load_image_dataset(rootpath+'\image_classification\chihuahua-muffin', maxsize)
#     (test_images, test_labels) = load_image_dataset(rootpath+'\image_classification\chihuahua-muffin/test_set', maxsize)
    print(train_images.shape)
    train_images, train_labels = shuffle_examples(train_images, train_labels)
    test_images, test_labels = shuffle_examples(test_images, test_labels)
    print('here')
    data={
        'train_images': np.reshape(train_images,(train_images.shape[0],-1)),
        'train_labels':train_labels.reshape(-1,1),
        'test_images':np.reshape(test_images,(test_images.shape[0],-1)),
        'test_labels':test_labels.reshape(-1,1)
    }
    save_data(data)
    
else:
    print('found')
    train_images = np.load('train_images.npy')
    train_labels = np.load('train_labels.npy')
    test_images = np.load('test_images.npy')
    test_labels = np.load('test_labels.npy')
    
    train_images= np.reshape(train_images,(train_images.shape[0],maxsize))
    test_images= np.reshape(test_images,(test_images.shape[0],maxsize))
# Out:
# (27, 100, 100)
# here
# here1
# (27, 10000)

# %%
# class_names = ['chihuahua', 'muffin']
class_names = ['plastic', 'paper']

# %%
print(train_images.shape)
# Out:
# (27, 100, 100)

# %%
print(train_labels.shape)
# Out:
# (27,)

# %%
print(test_images.shape)
print(test_labels)
# Out:
# (14, 100, 100)
# [1 0 0 1 0 1 1 0 1 1 0 0 0 1]

# %%
def display_images(images, labels):
        plt.figure(figsize=(10,10))
        grid_size = min(25, len(images))
        for i in range(grid_size):
                plt.subplot(5, 5, i+1)
                plt.xticks([])
                plt.yticks([])
                plt.grid(False)
                plt.imshow(images[i], cmap=plt.cm.binary)
                plt.xlabel(class_names[labels[i]])

# %%
display_images(train_images, train_labels)
plt.show()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0
print(train_images.shape)
print(test_images.shape)
# Out:
# (27, 100, 100)
# (14, 100, 100)

# %%
# Setting up the layers.

# model = keras.Sequential([
#     keras.layers.Flatten(input_shape=(100, 100)),
#         keras.layers.Dense(128, activation=tf.nn.sigmoid),
#         keras.layers.Dense(16, activation=tf.nn.sigmoid),
#     keras.layers.Dense(2, activation=tf.nn.softmax)
# ])

model = keras.models.Sequential([
                keras.layers.Flatten(input_shape = ( 100, 100)),
                keras.layers.Dense(512, activation=tf.nn.relu),
                keras.layers.Dropout(0.5),
                keras.layers.Dense(128, activation=tf.nn.relu),
                keras.layers.Dense(16, activation=tf.nn.relu),
        keras.layers.Dense(2, activation=tf.nn.softmax)
        ])

# model = keras.models.Sequential([
#                 keras.layers.Flatten(input_shape = ( 100, 100)),
#                 keras.layers.Dense(1024, activation=tf.nn.relu),
#                 keras.layers.Dropout(0.5),
#                 keras.layers.Dense(512, activation=tf.nn.relu),
#                 keras.layers.Dropout(0.5),
#                 keras.layers.Dense(64, activation=tf.nn.relu),
#                 keras.layers.Dense(16, activation=tf.nn.relu),
#         keras.layers.Dense(2, activation=tf.nn.softmax)
#         ])

# %%
sgd = keras.optimizers.SGD(lr=0.01, decay=1e-5, momentum=0.7, nesterov=True)

model.compile(optimizer=sgd,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=100)
# Out:
# Train on 27 samples
# Epoch 1/100
# 27/27 [==============================] - 1s 46ms/sample - loss: 0.7693 - accuracy: 0.4074
# Epoch 2/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.7843 - accuracy: 0.4815
# Epoch 3/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6669 - accuracy: 0.5556
# Epoch 4/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.7106 - accuracy: 0.5185
# Epoch 5/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.7057 - accuracy: 0.4815
# Epoch 6/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6437 - accuracy: 0.5185
# Epoch 7/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6583 - accuracy: 0.5926
# Epoch 8/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.6482 - accuracy: 0.7037
# Epoch 9/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.5906 - accuracy: 0.8148
# Epoch 10/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6772 - accuracy: 0.5185
# Epoch 11/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6831 - accuracy: 0.5185
# Epoch 12/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.7538 - accuracy: 0.4815
# Epoch 13/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.6908 - accuracy: 0.6296
# Epoch 14/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.5703 - accuracy: 0.7778
# Epoch 15/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6229 - accuracy: 0.7407
# Epoch 16/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6260 - accuracy: 0.5556
# Epoch 17/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6874 - accuracy: 0.5185
# Epoch 18/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6023 - accuracy: 0.7778
# Epoch 19/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6699 - accuracy: 0.6296
# Epoch 20/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.5976 - accuracy: 0.7037
# Epoch 21/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6169 - accuracy: 0.6296
# Epoch 22/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.5531 - accuracy: 0.7407
# Epoch 23/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.5230 - accuracy: 0.7407
# Epoch 24/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6220 - accuracy: 0.5926
# Epoch 25/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.5706 - accuracy: 0.6296
# Epoch 26/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.5220 - accuracy: 0.7778
# Epoch 27/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.4491 - accuracy: 0.8519
# Epoch 28/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.4822 - accuracy: 0.7407
# Epoch 29/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.5770 - accuracy: 0.7778
# Epoch 30/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.7336 - accuracy: 0.6296
# Epoch 31/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.5092 - accuracy: 0.7407
# Epoch 32/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.5486 - accuracy: 0.8519
# Epoch 33/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.5415 - accuracy: 0.6667
# Epoch 34/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6180 - accuracy: 0.7037
# Epoch 35/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.5461 - accuracy: 0.7778
# Epoch 36/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.4731 - accuracy: 0.8148
# Epoch 37/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.4544 - accuracy: 0.7778
# Epoch 38/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3901 - accuracy: 0.9259
# Epoch 39/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.4505 - accuracy: 0.7778
# Epoch 40/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.3729 - accuracy: 0.8519
# Epoch 41/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.4053 - accuracy: 0.7778
# Epoch 42/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.3653 - accuracy: 0.8889
# Epoch 43/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.5124 - accuracy: 0.7778
# Epoch 44/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.4668 - accuracy: 0.6667
# Epoch 45/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.7478 - accuracy: 0.5556
# Epoch 46/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.6201 - accuracy: 0.5556
# Epoch 47/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.4685 - accuracy: 0.7778
# Epoch 48/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.4523 - accuracy: 0.8519
# Epoch 49/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.3993 - accuracy: 0.8519
# Epoch 50/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.3887 - accuracy: 0.8519
# Epoch 51/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3186 - accuracy: 0.9259
# Epoch 52/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3545 - accuracy: 0.8889
# Epoch 53/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 1.0697 - accuracy: 0.5926
# Epoch 54/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 1.0923 - accuracy: 0.5185
# Epoch 55/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.4041 - accuracy: 0.8519
# Epoch 56/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.4437 - accuracy: 0.8519
# Epoch 57/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3789 - accuracy: 0.8519
# Epoch 58/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.2966 - accuracy: 0.9259
# Epoch 59/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3514 - accuracy: 0.8889
# Epoch 60/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.3745 - accuracy: 0.8148
# Epoch 61/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.2974 - accuracy: 0.9630
# Epoch 62/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3076 - accuracy: 0.9259
# Epoch 63/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3262 - accuracy: 0.8889
# Epoch 64/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.2321 - accuracy: 0.9259
# Epoch 65/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.1972 - accuracy: 0.9259
# Epoch 66/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.3105 - accuracy: 0.8519
# Epoch 67/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.2538 - accuracy: 0.9259
# Epoch 68/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.2613 - accuracy: 0.8889
# Epoch 69/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.4123 - accuracy: 0.8519
# Epoch 70/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3710 - accuracy: 0.8148
# Epoch 71/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.4517 - accuracy: 0.8519
# Epoch 72/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.5801 - accuracy: 0.6667
# Epoch 73/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.6042 - accuracy: 0.6296
# Epoch 74/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3762 - accuracy: 0.8519
# Epoch 75/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.2855 - accuracy: 0.9630
# Epoch 76/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.2393 - accuracy: 0.8889
# Epoch 77/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.2267 - accuracy: 0.9259
# Epoch 78/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.2386 - accuracy: 0.9259
# Epoch 79/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.4052 - accuracy: 0.8889
# Epoch 80/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3383 - accuracy: 0.8519
# Epoch 81/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.2090 - accuracy: 0.9259
# Epoch 82/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.1901 - accuracy: 0.9630
# Epoch 83/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.1647 - accuracy: 0.9630
# Epoch 84/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.1546 - accuracy: 0.9630
# Epoch 85/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.2548 - accuracy: 0.8889
# Epoch 86/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.3442 - accuracy: 0.7407
# Epoch 87/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3813 - accuracy: 0.7407
# Epoch 88/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.4274 - accuracy: 0.7407
# Epoch 89/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.4094 - accuracy: 0.8519
# Epoch 90/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3911 - accuracy: 0.8148
# Epoch 91/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.5489 - accuracy: 0.7407
# Epoch 92/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.3811 - accuracy: 0.8889
# Epoch 93/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.3406 - accuracy: 0.8148
# Epoch 94/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.2606 - accuracy: 0.8889
# Epoch 95/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.1932 - accuracy: 0.9630
# Epoch 96/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.1862 - accuracy: 0.9259
# Epoch 97/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.2000 - accuracy: 0.9630
# Epoch 98/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.1381 - accuracy: 0.9630
# Epoch 99/100
# 27/27 [==============================] - 0s 1ms/sample - loss: 0.1057 - accuracy: 1.0000
# Epoch 100/100
# 27/27 [==============================] - 0s 2ms/sample - loss: 0.1478 - accuracy: 0.9630

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 14/1 [====================================================================================================================================================================================================================================================================================================================================================================================================================================] - 0s 11ms/sample - loss: 0.4407 - accuracy: 0.7857
# Test accuracy: 0.78571427

# %%
predictions = model.predict(test_images)

# %%
print(predictions)
# Out:
# [[0.24622552 0.7537745 ]
#  [0.74854696 0.25145298]
#  [0.39601013 0.60398984]
#  [0.34589452 0.6541054 ]
#  [0.3463193  0.6536807 ]
#  [0.73276293 0.26723704]
#  [0.01250733 0.9874927 ]
#  [0.842162   0.15783803]
#  [0.07313503 0.926865  ]
#  [0.48540032 0.5145996 ]
#  [0.85611117 0.14388879]
#  [0.9315226  0.0684774 ]
#  [0.860475   0.13952503]
#  [0.43150732 0.56849265]]

# %%
display_images(test_images, np.argmax(predictions, axis = 1))
plt.show()

# %% [markdown]
# keep the images you want to classify in 'unknown' folder

# %%
# serialize model to JSON
# model_json = model.to_json()
# with open(rootpath+"\image_classification\model.json", "w") as json_file:
#     json_file.write(model_json)
# # serialize weights to HDF5
# model.save_weights(rootpath+"\image_classification\model.h5")
# print("Saved model to disk")

(test_image, label) = load_image_dataset(rootpath+'/image_classification/unknown', maxsize)

predictons=model.predict(test_image)
print(predictions)
display_images(test_image, np.argmax(predictions, axis = 1))
plt.show()
# Out:
# [[0.24622552 0.7537745 ]
#  [0.74854696 0.25145298]
#  [0.39601013 0.60398984]
#  [0.34589452 0.6541054 ]
#  [0.3463193  0.6536807 ]
#  [0.73276293 0.26723704]
#  [0.01250733 0.9874927 ]
#  [0.842162   0.15783803]
#  [0.07313503 0.926865  ]
#  [0.48540032 0.5145996 ]
#  [0.85611117 0.14388879]
#  [0.9315226  0.0684774 ]
#  [0.860475   0.13952503]
#  [0.43150732 0.56849265]]
